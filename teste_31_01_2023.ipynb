# %%
from source.vvc_execute_simulation import vvc_execute_simulation
from source.common.commonlib import read_config_file, compile_VTM
from os import getcwd
from os.path import join

config_file = 'auxiliar_files/cfg_home_ubuntu.txt'
data = read_config_file(config_file)

output_dir = join(getcwd(), 'output_31012023')
cfg_vid_dir = data['cfg_videos_dir']
vtm_path = data['vtm_dir']

vvc_execute_simulation(
    cfg_vid_dir=cfg_vid_dir, 
    output_dir=output_dir, 
    vtm_path=vtm_path, 
    num_frames=32, 
)
# Out:
# {'vtm_dir': '/home/luismendes/Desktop/VVCresearch/VVCSoftware_VTM', 'cfg_videos_dir': '/home/luismendes/Desktop/VVCresearch/cfg-files-test', 'out_videos_dir': '/home/luismendes/Desktop/VVCresearch/output_01'}
#
# Encoding: ........... BasketballPass
#
# Video config: ....... /home/luismendes/Desktop/VVCresearch/cfg-files-test/BasketballPass.cfg
# Encoder: ............ AI
# QP: ................. 22
# VTM version used: ... Precise
# frames encoded: ..... 8
#
#
# Encoding: ........... BasketballPass
#
# Video config: ....... /home/luismendes/Desktop/VVCresearch/cfg-files-test/BasketballPass.cfg
# Encoder: ............ LB
# QP: ................. 22
# VTM version used: ... Precise
# frames encoded: ..... 8
#
#
# Encoding: ........... BasketballPass
#
# Video config: ....... /home/luismendes/Desktop/VVCresearch/cfg-files-test/BasketballPass.cfg
# Encoder: ............ RA
# QP: ................. 22
# VTM version used: ... Precise
# frames encoded: ..... 8
#
#
# Encoding: ........... BasketballPass
#
# Video config: ....... /home/luismendes/Desktop/VVCresearch/cfg-files-test/BasketballPass.cfg
# Encoder: ............ AI
# QP: ................. 27
# VTM version used: ... Precise
# frames encoded: ..... 8
#
#
# Encoding: ........... BasketballPass
#
# Video config: ....... /home/luismendes/Desktop/VVCresearch/cfg-files-test/BasketballPass.cfg
# Encoder: ............ LB
# QP: ................. 27
# VTM version used: ... Precise
# frames encoded: ..... 8
#
#
# Encoding: ........... BasketballPass
#
# Video config: ....... /home/luismendes/Desktop/VVCresearch/cfg-files-test/BasketballPass.cfg
# Encoder: ............ RA
# QP: ................. 27
# VTM version used: ... Precise
# frames encoded: ..... 8
#
#
# Encoding: ........... BasketballPass
#
# Video config: ....... /home/luismendes/Desktop/VVCresearch/cfg-files-test/BasketballPass.cfg
# Encoder: ............ AI
# QP: ................. 32
# VTM version used: ... Precise
# frames encoded: ..... 8
#
#
# Encoding: ........... BasketballPass
#
# Video config: ....... /home/luismendes/Desktop/VVCresearch/cfg-files-test/BasketballPass.cfg
# Encoder: ............ LB
# QP: ................. 32
# VTM version used: ... Precise
# frames encoded: ..... 8
#
#
# Encoding: ........... BasketballPass
#
# Video config: ....... /home/luismendes/Desktop/VVCresearch/cfg-files-test/BasketballPass.cfg
# Encoder: ............ RA
# QP: ................. 32
# VTM version used: ... Precise
# frames encoded: ..... 8
#
#
# Encoding: ........... BasketballPass
#
# Video config: ....... /home/luismendes/Desktop/VVCresearch/cfg-files-test/BasketballPass.cfg
# Encoder: ............ AI
# QP: ................. 37
# VTM version used: ... Precise
# frames encoded: ..... 8
#
#
# Encoding: ........... BasketballPass
#
# Video config: ....... /home/luismendes/Desktop/VVCresearch/cfg-files-test/BasketballPass.cfg
# Encoder: ............ LB
# QP: ................. 37
# VTM version used: ... Precise
# frames encoded: ..... 8
#
#
# Encoding: ........... BasketballPass
#
# Video config: ....... /home/luismendes/Desktop/VVCresearch/cfg-files-test/BasketballPass.cfg
# Encoder: ............ RA
# QP: ................. 37
# VTM version used: ... Precise
# frames encoded: ..... 8

# %%
import source.gprof_log_analysis
