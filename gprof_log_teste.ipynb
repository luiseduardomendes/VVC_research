# %%
from source.gprof_log_analysis.gprof_log import GprofDF

test_file = 'C:\\Users\\dudup\\OneDrive\\Área de Trabalho\\New folder\\VVC\\VVC_research\\database\\output_analyser\\data\\akiyo.txt'
gdf = GprofDF() 

gdf.read_file(test_file)
# Out:
#       time  cum_sec  self_sec       calls self_s_call tot_s_call  \
# 0     5.88     3.02      3.02   5798885.0         0.0        0.0
# 1     4.31     5.23      2.21  35143650.0         0.0        0.0
# 2     3.08     6.81      1.58   3805699.0         0.0        0.0
# 3     2.86     8.28      1.47   4164923.0         0.0        0.0
# 4     2.47     9.55      1.27  31407280.0         0.0        0.0
# ...    ...      ...       ...         ...         ...        ...
# 3003  0.00     0.00       0.0         1.0
# 3004  0.00     0.00       0.0         1.0
# 3005  0.00     0.00       0.0
# 3006  0.00     0.00       0.0         1.0
# 3007  0.00     0.00       0.0         1.0
#
#                           name                 class
# 0               gnsCholeskyDec         AlfCovariance
# 1         xGetSAD_NxN_SIMD<4,   unsigned long RdCost
# 2                xPredIntraAng       IntraPrediction
# 3     residual_coding_subblock           CABACWriter
# ...
