# %%
import vvc_log as vl
qps = (22, 27, 32, 37)
files = ('BQMall', 'RaceHorses')
dfs = []
for file in files:
    for qp in qps:
        dfs.append(vl.read_log(f'../out/4x4-1-RdCost4x4-1-8x8-SAD/{file}/intra/exec_log/log_{file}_qp{qp}_intra_4x4-1-RdCost4x4-1-8x8-SAD_exec.gplog'))

dfs = vl.split(dfs)
for key in dfs.keys():
    dfs[key].getDataFrame().plot('bitrate')
