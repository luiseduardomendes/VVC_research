# %%
import gprof_log as gl

dt = gl.read_gprof_out('../data/akiyo.txt', 10000)
dt = dt[dt['class']=='RdCost']

dt
# Out:
#       time  cum_sec  self_sec      calls self_s_call tot_s_call  \
# 25    0.71    22.39      0.37  1544158.0         0.0        0.0
# 28    0.63    23.41      0.33   782148.0         0.0        0.0
# 33    0.56    24.89      0.29   228269.0         0.0        0.0
# 95    0.25    37.28      0.13  1510721.0         0.0        0.0
# 97    0.25    37.54      0.13    26713.0         0.0        0.0
# 106   0.22    38.61      0.12  6880094.0         0.0        0.0
# 239   0.06    47.00      0.03  9075200.0         0.0        0.0
# 258   0.06    47.57      0.03   426208.0         0.0        0.0
# 275   0.05    48.07      0.03  6799423.0         0.0        0.0
# 297   0.04    48.55      0.02  1476516.0         0.0        0.0
# 389   0.02    50.09      0.01  2651342.0         0.0        0.0
# 395   0.02    50.15      0.01  1607222.0         0.0        0.0
# 486   0.02    51.06      0.01
# 498   0.01    51.15      0.01  1199884.0         0.0        0.0
# ...
