# %%
import gprof_log as gl

gl.read_gprof_out('../data/akiyo.txt', 10)
# Out:
#    time  cum_sec   self_sec       calls  self_s_call  tot_s_call  \
# 0  5.88     3.02       3.02   5798885.0         0.00        0.00
# 1  4.31     5.23       2.21  35143650.0         0.00        0.00
# 2  3.08     6.81       1.58   3805699.0         0.00        0.00
# 3  2.86     8.28       1.47   4164923.0         0.00        0.00
# 4  2.47     9.55       1.27  31407280.0         0.00        0.00
# 5  2.40    10.78       1.23   2408848.0         0.00        0.00
# 6  2.24    11.93       1.15   5696382.0         0.00        0.00
# 7  2.18    13.05       1.12  31407280.0         0.00        0.00
# 8  1.48    13.81       0.76   5696382.0         0.00        0.00
# 9  1.48    14.57       0.76       120.0         0.01        0.01
#
#                            name                  class
# 0                gnsCholeskyDec          AlfCovariance
# 1          xGetSAD_NxN_SIMD<4,    unsigned long RdCost
# 2                 xPredIntraAng        IntraPrediction
# ...
