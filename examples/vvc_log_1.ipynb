# %%
from vvc_performance import VVC_Output, vvc_log_path
from pprint import pprint
from os.path import isfile

qps = (22, 27, 32, 37)
file = 'BasketballPass'
cfg = 'AI'
dir = 'output'
vers = 'Precise'
videos = vvc_log_path(dir, cfg, file, vers, qps, True)

VVC_Output().read_multifile(videos, qps, False)
# Out:
# [('4869.3250', '43.6037', '45.8249', '46.1798', '44.2646'), ('4866.2000', '43.6049', '45.7918', '46.1498', '44.2583')]
# [('2861.6750', '40.1072', '42.5179', '42.6368', '40.7845'), ('2859.0875', '40.1055', '42.5323', '42.6610', '40.7874')]
# [('1587.0625', '36.6794', '39.7524', '39.6862', '37.4759'), ('1588.4875', '36.6857', '39.7242', '39.7198', '37.4816')]
# [('866.7250', '33.5711', '38.1376', '37.9891', '34.6203'), ('866.6375', '33.5744', '38.0821', '37.9879', '34.6189')]
#    frame  t_frame  qp_offset    bitrate   Y_PSNR   U_PSNR   V_PSNR  YUV_PSNR  \
# 0     -1      NaN        NaN  4869.3250  43.6037  45.8249  46.1798   44.2646
# 0     -1      NaN        NaN  2861.6750  40.1072  42.5179  42.6368   40.7845
# 0     -1      NaN        NaN  1587.0625  36.6794  39.7524  39.6862   37.4759
# 0     -1      NaN        NaN   866.7250  33.5711  38.1376  37.9891   34.6203
#
#    qp
# 0  22
# 0  27
# 0  32
# 0  37
