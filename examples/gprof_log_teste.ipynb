# %%
from vvc_performance import GprofDF, gprof_log_path

file = gprof_log_path(
    path='output', 
    cfg='AI', 
    file='BasketballPass', 
    version='Precise', 
    qps=22, 
    multiqp=False
)
gdf = GprofDF() 

gdf.read_file(file)
# Out:
#       time  cum_sec  self_sec         calls  self_s_call  tot_s_call  \
# 0     8.36   118.24    118.24  2.065271e+09          0.0         0.0
# 1     6.89   215.78     97.54  1.913780e+08          0.0         0.0
# 2     6.00   300.61     84.83  2.065271e+09          0.0         0.0
# 3     4.14   359.18     58.57  2.279776e+08          0.0         0.0
# 4     3.78   412.61     53.43  1.128437e+08          0.0         0.0
# ...    ...      ...       ...           ...          ...         ...
# 2459  0.00  1990.71      0.00  1.000000e+00          0.0         0.0
# 2460  0.00     0.00       NaN  2.660000e+02          NaN         NaN
# 2461  0.00     0.00       NaN  2.040000e+02          NaN         NaN
# 2462  0.00     0.00       NaN  4.000000e+00          NaN         NaN
# 2463  0.00     0.00       NaN  4.000000e+00          NaN         NaN
#
#                  namespace                 class                  function  \
# ...
